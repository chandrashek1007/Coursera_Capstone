# %% [markdown]
# # Segmenting and Clustering Neighborhoods in New York City

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this project, I am extracting postal codes, Borough and Neighborhood of Canada using Web Scraping (Beautifulsoup) and then converting addresses into their equivalent latitude and longitude values. Also, I am using the Foursquare API to explore neighborhoods in Toronto City. I am using **explore** function to get the most common venue categories in each neighborhood, and then use this feature to group the neighborhoods into clusters. I am using the *k*-means clustering algorithm to complete this task. Finally, I am using the Folium library to visualize the neighborhoods in Toronto City and their emerging clusters.

# %% [markdown]
# ### 1. Extracting Data from webpage to make Dataset

# %% [markdown]
# <div id='#item1'> As there is no Dataset of Canada directly availaible. So we are creating our own Dataset by Web Scraping data from the website <a href='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'>https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M</a> using Beautifulsoup package python </div>

# %% [markdown]
# #### Step 1 : Importing All Libraries

# %%
#Beautifulsoup library helps in web scraping data from webpage
from bs4 import BeautifulSoup
#lxml library is the parser used to parse the content from diffrent HTML Tags
import lxml
# Requests library helps in getting the content of the webpage
import requests as req
# library to handle data in a vectorized manner
import numpy as np
#library for Data Analysis
import pandas as pd
# library to handle JSON files
import json 
# convert an address into latitude and longitude values
from geopy.geocoders import Nominatim 
# library to handle requests
import requests 
# tranform JSON file into a pandas dataframe
from pandas.io.json import json_normalize 
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans
# map rendering library
import folium 
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Step 2 : Web Scraping Data from the Webpage
# We are extracting the data and writing the filtered data in the CSV file which is **demofile.csv**. After this step we are getting our raw dataset of Canada.

# %%
r = req.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(r.content,'lxml')
f = open("demofile.csv", "w")

hd=""
for header in soup.find_all('th'):
    hd=hd+','+header.text
hd=hd[1:31]

f.write(hd+'\n')
count=0
for record in soup.find_all('tr'):
    count+=1
    tdata=""
    for data in record.find_all('td'):
        tdata=tdata+','+data.text
    tdata=tdata[1:]
    if count==290:
        f.write(tdata)
        break
    f.write(tdata)
f.close()

# %% [markdown]
# #### Step 3: Reading the demofile.csv to dat dataframe. We can verify the content of dat dataframe using **dat.head()**.

# %%
dat=pd.read_csv('demofile.csv')
dat.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# #### Step 4: Converting the 'Not Assigned' values to NaN in dat dataframe.

# %%
dat.replace('Not assigned',np.NaN,inplace=True)

# %% [markdown]
# #### Step 5: Droping the rows whose **Borough** is NaN.

# %%
dat.dropna(subset=['Borough'],inplace=True)

# %% [markdown]
# #### Step 6: If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough

# %%
for index, row in dat.iterrows():
    if row['Neighbourhood']== 'NaN' or row['Neighbourhood']== '':
        row['Neighbourhood']=row['Borough']
    if row["Postcode"]=='M7A':
        row['Neighbourhood']=row['Borough']

# %% [markdown]
# #### Step 7: More than one neighborhood can exist in one postal code area. Those two rows will be combined into one row with the neighborhoods separated with a comma .

# %%
dat.Neighbourhood = dat.Neighbourhood.astype(str)
dat= dat.groupby(['Postcode','Borough'])['Neighbourhood'].apply(', '.join).reset_index()
s=pd.Series(range(1,104)) 
dat.set_index(s,inplace=True)

# %% [markdown]
# ### Step 8: Print the .shape method to print the number of rows of your dataframe.

# %%
dat.shape
# Out:
# (103, 3)

# %% [markdown]
# Now that I have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.
# Using the Geocoder package or the csv file to create the following dataframe:

# %%
geospat_data=pd.read_csv('Geospatial_Coordinates.csv')
count=0
dat_lat=[]
dat_lon=[]
for index1, row1 in dat.iterrows():
    for index2,row2 in geospat_data.iterrows():
        if str(row1["Postcode"])==str(row2["Postal Code"]):
            a=row2["Longitude"]
            b=row2["Latitude"]
            dat_lat.append(b)
            dat_lon.append(a)
dat['Longitude']=dat_lon
dat['Latitude']=dat_lat
dat.isnull().sum(axis=0)  
dat.to_csv('int_data.csv')
dat
# Out:
#     Postcode           Borough  \
# 1        M1B       Scarborough
# 2        M1C       Scarborough
# 3        M1E       Scarborough
# 4        M1G       Scarborough
# 5        M1H       Scarborough
# 6        M1J       Scarborough
# 7        M1K       Scarborough
# 8        M1L       Scarborough
# 9        M1M       Scarborough
# 10       M1N       Scarborough
# 11       M1P       Scarborough
# 12       M1R       Scarborough
# 13       M1S       Scarborough
# 14       M1T       Scarborough
# 15       M1V       Scarborough
# 16       M1W       Scarborough
# 17       M1X       Scarborough
# 18       M2H        North York
# 19       M2J        North York
# 20       M2K        North York
# 21       M2L        North York
# 22       M2M        North York
# 23       M2N        North York
# 24       M2P        North York
# 25       M2R        North York
# 26       M3A        North York
# 27       M3B        North York
# 28       M3C        North York
# 29       M3H        North York
# 30       M3J        North York
# ..       ...               ...
# 74       M6C              York
# 75       M6E              York
# 76       M6G  Downtown Toronto
# 77       M6H      West Toronto
# 78       M6J      West Toronto
# 79       M6K      West Toronto
# 80       M6L        North York
# 81       M6M              York
# 82       M6N              York
# 83       M6P      West Toronto
# 84       M6R      West Toronto
# 85       M6S      West Toronto
# 86       M7A      Queen's Park
# 87       M7R       Mississauga
# 88       M7Y      East Toronto
# 89       M8V         Etobicoke
# 90       M8W         Etobicoke
# 91       M8X         Etobicoke
# 92       M8Y         Etobicoke
# 93       M8Z         Etobicoke
# 94       M9A         Etobicoke
# 95       M9B         Etobicoke
# 96       M9C         Etobicoke
# 97       M9L        North York
# 98       M9M        North York
# 99       M9N              York
# 100      M9P         Etobicoke
# 101      M9R         Etobicoke
# 102      M9V         Etobicoke
# 103      M9W         Etobicoke
#
#                                          Neighbourhood  Longitude   Latitude
# 1                                       Rouge, Malvern -79.194353  43.806686
# 2               Highland Creek, Rouge Hill, Port Union -79.160497  43.784535
# 3                    Guildwood, Morningside, West Hill -79.188711  43.763573
# 4                                               Woburn -79.216917  43.770992
# 5                                            Cedarbrae -79.239476  43.773136
# 6                                  Scarborough Village -79.239476  43.744734
# 7          East Birchmount Park, Ionview, Kennedy Park -79.262029  43.727929
# 8                      Clairlea, Golden Mile, Oakridge -79.284577  43.711112
# 9      Cliffcrest, Cliffside, Scarborough Village West -79.239476  43.716316
# 10                         Birch Cliff, Cliffside West -79.264848  43.692657
# 11   Dorset Park, Scarborough Town Centre, Wexford ... -79.273304  43.757410
# 12                                   Maryvale, Wexford -79.295849  43.750072
# 13                                           Agincourt -79.262029  43.794200
# 14             Clarks Corners, Sullivan, Tam O'Shanter -79.304302  43.781638
# 15   Agincourt North, L'Amoreaux East, Milliken, St... -79.284577  43.815252
# 16                       L'Amoreaux West, Steeles West -79.318389  43.799525
# 17                                         Upper Rouge -79.205636  43.836125
# 18                                   Hillcrest Village -79.363452  43.803762
# 19                        Fairview, Henry Farm, Oriole -79.346556  43.778517
# 20                                     Bayview Village -79.385975  43.786947
# 21                            Silver Hills, York Mills -79.374714  43.757490
# 22                             Newtonbrook, Willowdale -79.408493  43.789053
# 23                                    Willowdale South -79.408493  43.770120
# 24                                     York Mills West -79.400049  43.752758
# 25                                     Willowdale West -79.442259  43.782736
# 26                                           Parkwoods -79.329656  43.753259
# 27                                     Don Mills North -79.352188  43.745906
# 28                    Flemingdon Park, Don Mills South -79.340923  43.725900
# 29     Bathurst Manor, Downsview North, Wilson Heights -79.442259  43.754328
# 30                     Northwood Park, York University -79.487262  43.767980
# ..                                                 ...        ...        ...
# 74                                  Humewood-Cedarvale -79.428191  43.693781
# 75                                 Caledonia-Fairbanks -79.453512  43.689026
# 76                                            Christie -79.422564  43.669542
# 77                        Dovercourt Village, Dufferin -79.442259  43.669005
# 78                            Little Portugal, Trinity -79.419750  43.647927
# 79        Brockton, Exhibition Place, Parkdale Village -79.428191  43.636847
# 80            Maple Leaf Park, North Park, Upwood Park -79.490074  43.713756
# 81      Del Ray, Keelesdale, Mount Dennis, Silverthorn -79.476013  43.691116
# 82                       The Junction North, Runnymede -79.487262  43.673185
# 83                       High Park, The Junction South -79.464763  43.661608
# 84                              Parkdale, Roncesvalles -79.456325  43.648960
# 85                                  Runnymede, Swansea -79.484450  43.651571
# 86                                        Queen's Park -79.389494  43.662301
# 87               Canada Post Gateway Processing Centre -79.615819  43.636966
# 88   Business Reply Mail Processing Centre 969 Eastern -79.321558  43.662744
# 89        Humber Bay Shores, Mimico South, New Toronto -79.501321  43.605647
# 90                              Alderwood, Long Branch -79.543484  43.602414
# 91       The Kingsway, Montgomery Road, Old Mill North -79.506944  43.653654
# 92   Humber Bay, King's Mill Park, Kingsway Park So... -79.498509  43.636258
# 93   Kingsway Park South West, Mimico NW, The Queen... -79.520999  43.628841
# 94                                    Islington Avenue -79.532242  43.667856
# 95   Cloverdale, Islington, Martin Grove, Princess ... -79.554724  43.650943
# 96   Bloordale Gardens, Eringate, Markland Wood, Ol... -79.577201  43.643515
# 97                                       Humber Summit -79.565963  43.756303
# 98                                    Emery, Humberlea -79.532242  43.724766
# 99                                              Weston -79.518188  43.706876
# 100                                          Westmount -79.532242  43.696319
# 101  Kingsview Village, Martin Grove Gardens, Richv... -79.554724  43.688905
# 102  Albion Gardens, Beaumond Heights, Humbergate, ... -79.588437  43.739416
# 103                                          Northwest -79.594054  43.706748
#
# [103 rows x 5 columns]
